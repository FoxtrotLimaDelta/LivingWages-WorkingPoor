# %%
import xlrd
import pandas as pd
import pprint

# %%
book = xlrd.open_workbook('SNAP/FY19.xls')

# %%
for sheet in book.sheets():
    print (sheet.name)
# Out:
# NERO
# MARO
# SERO
# MWRO
# SWRO
# MPRO
# WRO
# US Summary

# %%
sheet = book.sheet_by_name('NERO')

# %%
for i in range(sheet.nrows):
    print(sheet.row_values(i))
# Out:
# ['National Data Bank Version 8.2 PUBLIC - Supplemental Nutrition Assistance Program', '', '', '', '', '07/01/2020']
# ['SNAP Monthly State Participation and Benefit Summary - Public Data, Fiscal Year 2019', '', '', '', '', '']
# [' ', '', '', '', '', '']
# ['', '', '', '', '', '']
# [' ', 'Total 1/', '', '', '', '']
# ['Fiscal Year and Month', 'Participation 1/', '', 'Cost', 'Cost Per', '']
# ['', 'Household', 'Persons', '', 'Household', 'Persons']
# ['Connecticut', '', '', '', '', '']
# ['Oct 2018', 217619.0, 376447.0, 50630409.0, 232.6562, 134.4955]
# ['Nov 2018', 216134.0, 374230.0, 50141937.0, 231.9947, 133.987]
# ['Dec 2018', 215283.0, 372079.0, 49717875.0, 230.9419, 133.6218]
# ['Jan 2019 /2', 215132.0, 371393.0, 96027525.0, 446.3656, 258.5604]
# ['Feb 2019 /2', 19891.0, 39270.0, 1894161.0, 95.227, 48.2343]
# ['Mar 2019', 213248.0, 366453.0, 48298979.0, 226.4921, 131.8013]
# ['Apr 2019', 212331.0, 364182.0, 47900307.0, 225.5926, 131.5285]
# ...

# %%
data_test = {
        ('Connecticut', 'October 2018'): {
            'household_participation': 1,
            'individual_participation': 1,
            'total_cost' : 1,
            'cost_by_household' : 1,
            'cost_by_individual': 1,
        },   
        ('Connecticut', 'November 2018'): {
            'household_participation': 1,
            'individual_participation': 1,
            'total_cost' : 1,
            'cost_by_household' : 1,
            'cost_by_individual': 1,            
            }
        }

# %%
pd.DataFrame.from_dict(data_test, orient = 'index')
# Out:
#                            household_participation  individual_participation  \
# Connecticut October 2018                         1                         1
#             November 2018                        1                         1
#
#                            total_cost  cost_by_household  cost_by_individual
# Connecticut October 2018            1                  1                   1
#             November 2018           1                  1                   1

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Connecticut', '', '', '', '', '']
# 8 ['Oct 2018', 217619.0, 376447.0, 50630409.0, 232.6562, 134.4955]
# 9 ['Nov 2018', 216134.0, 374230.0, 50141937.0, 231.9947, 133.987]
# 10 ['Dec 2018', 215283.0, 372079.0, 49717875.0, 230.9419, 133.6218]
# 11 ['Jan 2019 /2', 215132.0, 371393.0, 96027525.0, 446.3656, 258.5604]
# 12 ['Feb 2019 /2', 19891.0, 39270.0, 1894161.0, 95.227, 48.2343]
# 13 ['Mar 2019', 213248.0, 366453.0, 48298979.0, 226.4921, 131.8013]
# 14 ['Apr 2019', 212331.0, 364182.0, 47900307.0, 225.5926, 131.5285]
# 15 ['May 2019', 212602.0, 364456.0, 47981032.0, 225.6848, 131.6511]
# 16 ['Jun 2019', 212355.0, 363578.0, 47921516.0, 225.667, 131.8053]
# 17 ['Jul 2019', 212611.0, 364092.0, 48021204.0, 225.8642, 131.893]
# 18 ['Aug 2019', 213062.0, 364704.0, 48102772.0, 225.7689, 131.8954]
# 19 ['Sep 2019', 212861.0, 364474.0, 48080883.0, 225.8792, 131.9186]
# 20 ['Total', 197760.75, 340446.5, 584718600.0, 246.39140833333335, 143.125425]
# 21 ['', '', '', '', '', '']
# ...

# %%
for i in range(7, sheet.nrows):
    
    row = sheet.row_values(i)
    
    print(i,row)
# Out:
# 7 ['Connecticut', '', '', '', '', '']
# 8 ['Oct 2018', 217619.0, 376447.0, 50630409.0, 232.6562, 134.4955]
# 9 ['Nov 2018', 216134.0, 374230.0, 50141937.0, 231.9947, 133.987]
# 10 ['Dec 2018', 215283.0, 372079.0, 49717875.0, 230.9419, 133.6218]
# 11 ['Jan 2019 /2', 215132.0, 371393.0, 96027525.0, 446.3656, 258.5604]
# 12 ['Feb 2019 /2', 19891.0, 39270.0, 1894161.0, 95.227, 48.2343]
# 13 ['Mar 2019', 213248.0, 366453.0, 48298979.0, 226.4921, 131.8013]
# 14 ['Apr 2019', 212331.0, 364182.0, 47900307.0, 225.5926, 131.5285]
# 15 ['May 2019', 212602.0, 364456.0, 47981032.0, 225.6848, 131.6511]
# 16 ['Jun 2019', 212355.0, 363578.0, 47921516.0, 225.667, 131.8053]
# 17 ['Jul 2019', 212611.0, 364092.0, 48021204.0, 225.8642, 131.893]
# 18 ['Aug 2019', 213062.0, 364704.0, 48102772.0, 225.7689, 131.8954]
# 19 ['Sep 2019', 212861.0, 364474.0, 48080883.0, 225.8792, 131.9186]
# 20 ['Total', 197760.75, 340446.5, 584718600.0, 246.39140833333335, 143.125425]
# 21 ['', '', '', '', '', '']
# ...

# %%
data = {}
for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    #RULES: 
    
    row = sheet.row_values(i)
    
    if i in [x for x in range(7, sheet.nrows, 15)]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue         
    if i in [x for x in range(21, sheet.nrows, 15)]:
        continue
    
    #ROW BY ROW
    
    #month = row[0]
    
    #household_participation = row[1]
    
    

        
pprint.pprint(data)
# Out:
# {}

# %%
data = {}
for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [x for x in range(7, sheet.nrows, 15)]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [x for x in range(21, sheet.nrows, 15)]:
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data)
# Out:
# {('Illinois', 'Apr 2019'): {'0-household_participation': 864878.0,
#                             '1-individual_participation': 1737117.0,
#                             '2-total_cost': 214468054.0,
#                             '3-cost_by_household': 247.9749,
#                             '4-cost_by_individual': 123.4621},
#  ('Illinois', 'Aug 2019'): {'0-household_participation': 892071.0,
#                             '1-individual_participation': 1783530.0,
#                             '2-total_cost': 221401220.0,
#                             '3-cost_by_household': 248.1879,
#                             '4-cost_by_individual': 124.1365},
#  ('Illinois', 'Dec 2018'): {'0-household_participation': 883840.0,
#                             '1-individual_participation': 1777509.0,
#                             '2-total_cost': 222272631.0,
#                             '3-cost_by_household': 251.4851,
#                             '4-cost_by_individual': 125.0473},
# ...

# %%
pd.DataFrame.from_dict(data, orient = 'index')
# Out:
#                       0-household_participation  1-individual_participation  \
# Illinois Oct 2018                  8.856200e+05                   1783389.0
#          Nov 2018                  8.736690e+05                   1759510.0
#          Dec 2018                  8.838400e+05                   1777509.0
#          Jan 2019 /2               9.079530e+05                   1826750.0
#          Feb 2019 /2               6.491500e+04                    141914.0
# ...                                         ...                         ...
# MWRO     Jun 2019                  3.111026e+06                   6201910.0
#          Jul 2019                  3.091281e+06                   6163004.0
#          Aug 2019                  3.113797e+06                   6207063.0
#          Sep 2019                  3.107296e+06                   6191942.0
#          Total                     2.946123e+06                   5874793.0
#
# ...

# %%
sheet = book.sheet_by_name('MARO')

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Delaware', '', '', '', '', '']
# 8 ['Oct 2018', 66592.0, 136252.0, 15919691.0, 239.0631, 116.8401]
# 9 ['Nov 2018', 66006.0, 135049.0, 15833430.0, 239.8786, 117.2421]
# 10 ['Dec 2018', 65572.0, 134116.0, 15366657.0, 234.3478, 114.5774]
# 11 ['Jan 2019 /2', 67688.0, 138562.0, 29724419.0, 439.1387, 214.5207]
# 12 ['Feb 2019 /2', 4591.0, 9847.0, 1058418.0, 230.5419, 107.4863]
# 13 ['Mar 2019', 63714.0, 130125.0, 14834373.0, 232.8275, 114.0009]
# 14 ['Apr 2019', 62920.0, 128321.0, 14553838.0, 231.307, 113.4174]
# 15 ['May 2019', 62535.0, 127545.0, 14483248.0, 231.6023, 113.554]
# 16 ['Jun 2019', 61742.0, 125758.0, 14314398.0, 231.8421, 113.8249]
# 17 ['Jul 2019', 60991.0, 124488.0, 14062844.0, 230.5724, 112.9655]
# 18 ['Aug 2019', 61275.0, 125239.0, 14243888.0, 232.4584, 113.7336]
# 19 ['Sep 2019', 59840.0, 122139.0, 13743381.0, 229.6688, 112.5225]
# 20 ['Total', 58622.1667, 119786.75, 178138585.0, 253.22984166666666, 123.92758333333333]
# 21 ['', '', '', '', '', '']
# ...

# %%
data2 = {}

for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [7,22,37,52,67,82,84,99,114,129]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [21,36,51,66,81,98,113,128]:
        #for the rows that have blanks
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data2[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data2)
# Out:
# {('Illinois', 'Apr 2019'): {'0-household_participation': 864878.0,
#                             '1-individual_participation': 1737117.0,
#                             '2-total_cost': 214468054.0,
#                             '3-cost_by_household': 247.9749,
#                             '4-cost_by_individual': 123.4621},
#  ('Illinois', 'Aug 2019'): {'0-household_participation': 892071.0,
#                             '1-individual_participation': 1783530.0,
#                             '2-total_cost': 221401220.0,
#                             '3-cost_by_household': 248.1879,
#                             '4-cost_by_individual': 124.1365},
#  ('Illinois', 'Dec 2018'): {'0-household_participation': 883840.0,
#                             '1-individual_participation': 1777509.0,
#                             '2-total_cost': 222272631.0,
#                             '3-cost_by_household': 251.4851,
#                             '4-cost_by_individual': 125.0473},
# ...

# %%
sheet = book.sheet_by_name('SERO')

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Alabama', '', '', '', '', '']
# 8 ['Oct 2018', 352543.0, 748755.0, 90640836.0, 257.1058, 121.0554]
# 9 ['Nov 2018', 350510.0, 743517.0, 88391600.0, 252.18, 118.8831]
# 10 ['Dec 2018', 348807.0, 739258.0, 88413840.0, 253.475, 119.5981]
# 11 ['Jan 2019 /2', 346977.0, 734098.0, 163797737.0, 472.0709, 223.1279]
# 12 ['Feb 2019 /2', 1663.0, 3926.0, 7478420.0, 4496.9453, 1904.8446]
# 13 ['Mar 2019', 342619.0, 723596.0, 85184474.0, 248.6274, 117.7238]
# 14 ['Apr 2019', 339982.0, 717163.0, 84031740.0, 247.1653, 117.1724]
# 15 ['May 2019', 339642.0, 716989.0, 84389364.0, 248.4656, 117.6997]
# 16 ['Jun 2019', 339857.0, 717564.0, 84618427.0, 248.9824, 117.9246]
# 17 ['Jul 2019', 340639.0, 718523.0, 84716418.0, 248.6985, 117.9036]
# 18 ['Aug 2019', 341995.0, 721299.0, 85367868.0, 249.6173, 118.353]
# 19 ['Sep 2019', 341373.0, 719827.0, 85034162.0, 249.0946, 118.1314]
# 20 ['Total', 315550.5833, 667042.9167, 1032064886.0, 272.5566416666667, 128.93534166666666]
# 21 ['', '', '', '', '', '']
# ...

# %%
data3 = {}

for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [7,22,37,52,67,82,97,112,127,142]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [21,36,51,66,81,96,111,126,141]:
        #for the rows that have blanks
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data3[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data3)
# Out:
# {('Alabama', 'Apr 2019'): {'0-household_participation': 339982.0,
#                            '1-individual_participation': 717163.0,
#                            '2-total_cost': 84031740.0,
#                            '3-cost_by_household': 247.1653,
#                            '4-cost_by_individual': 117.1724},
#  ('Alabama', 'Aug 2019'): {'0-household_participation': 341995.0,
#                            '1-individual_participation': 721299.0,
#                            '2-total_cost': 85367868.0,
#                            '3-cost_by_household': 249.6173,
#                            '4-cost_by_individual': 118.353},
#  ('Alabama', 'Dec 2018'): {'0-household_participation': 348807.0,
#                            '1-individual_participation': 739258.0,
#                            '2-total_cost': 88413840.0,
#                            '3-cost_by_household': 253.475,
#                            '4-cost_by_individual': 119.5981},
# ...

# %%
sheet = book.sheet_by_name('MWRO')

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Illinois', '', '', '', '', '']
# 8 ['Oct 2018', 885620.0, 1783389.0, 228902676.0, 258.466, 128.3526]
# 9 ['Nov 2018', 873669.0, 1759510.0, 221428465.0, 253.4466, 125.8467]
# 10 ['Dec 2018', 883840.0, 1777509.0, 222272631.0, 251.4851, 125.0473]
# 11 ['Jan 2019 /2', 907953.0, 1826750.0, 422282439.0, 465.0928, 231.166]
# 12 ['Feb 2019 /2', 64915.0, 141914.0, 18120032.0, 279.1347, 127.6832]
# 13 ['Mar 2019', 875089.0, 1757209.0, 220254421.0, 251.6937, 125.3433]
# 14 ['Apr 2019', 864878.0, 1737117.0, 214468054.0, 247.9749, 123.4621]
# 15 ['May 2019', 885370.0, 1780778.0, 220362230.0, 248.8928, 123.7449]
# 16 ['Jun 2019', 882852.0, 1771527.0, 217608678.0, 246.4838, 122.8368]
# 17 ['Jul 2019', 889348.0, 1782949.0, 220378853.0, 247.7982, 123.6036]
# 18 ['Aug 2019', 892071.0, 1783530.0, 221401220.0, 248.1879, 124.1365]
# 19 ['Sep 2019', 886924.0, 1770574.0, 218556181.0, 246.4204, 123.438]
# 20 ['Total', 816044.0833, 1639396.3333, 2646035880.0, 270.2096583333333, 134.50255]
# ...

# %%
data4 = {}

for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [7,22,37,52,67,82,97,112,127,142]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [21,36,51,66,81,96,111,126,141]:
        #for the rows that have blanks
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data4[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data4)
# Out:
# {('Illinois', 'Apr 2019'): {'0-household_participation': 864878.0,
#                             '1-individual_participation': 1737117.0,
#                             '2-total_cost': 214468054.0,
#                             '3-cost_by_household': 247.9749,
#                             '4-cost_by_individual': 123.4621},
#  ('Illinois', 'Aug 2019'): {'0-household_participation': 892071.0,
#                             '1-individual_participation': 1783530.0,
#                             '2-total_cost': 221401220.0,
#                             '3-cost_by_household': 248.1879,
#                             '4-cost_by_individual': 124.1365},
#  ('Illinois', 'Dec 2018'): {'0-household_participation': 883840.0,
#                             '1-individual_participation': 1777509.0,
#                             '2-total_cost': 222272631.0,
#                             '3-cost_by_household': 251.4851,
#                             '4-cost_by_individual': 125.0473},
# ...

# %%
sheet = book.sheet_by_name('SWRO')

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Arizona', '', '', '', '', '']
# 8 ['Oct 2018', 386130.0, 834518.0, 100656542.0, 260.6804, 120.6164]
# 9 ['Nov 2018', 381440.0, 823176.0, 98897848.0, 259.275, 120.1418]
# 10 ['Dec 2018', 378525.0, 813790.0, 97746608.0, 258.2303, 120.1128]
# 11 ['Jan 2019 /2', 381800.0, 815689.0, 182138762.0, 477.0528, 223.2944]
# 12 ['Feb 2019 /2', 29081.0, 62271.0, 6925223.0, 238.1357, 111.211]
# 13 ['Mar 2019', 367418.0, 779723.0, 92956039.0, 252.9981, 119.2167]
# 14 ['Apr 2019', 362808.0, 769805.0, 92094926.0, 253.8393, 119.6341]
# 15 ['May 2019', 363819.0, 773157.0, 92665456.0, 254.7021, 119.8533]
# 16 ['Jun 2019', 368339.0, 783815.0, 94309681.0, 256.0404, 120.3214]
# 17 ['Jul 2019', 371735.0, 790722.0, 95736659.0, 257.5401, 121.075]
# 18 ['Aug 2019', 374946.0, 797795.0, 96298934.0, 256.8341, 120.7064]
# 19 ['Sep 2019', 375236.0, 798130.0, 96285536.0, 256.5999, 120.6389]
# 20 ['Total', 345106.4167, 736882.5833, 1146712214.0, 276.89821666666666, 129.68056666666666]
# ...

# %%
data5 = {}

for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [7,22,37,52,67,82,97,112,127,142]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [21,36,51,66,81,96,111,126,141]:
        #for the rows that have blanks
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data5[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data5)
# Out:
# {('Arizona', 'Apr 2019'): {'0-household_participation': 362808.0,
#                            '1-individual_participation': 769805.0,
#                            '2-total_cost': 92094926.0,
#                            '3-cost_by_household': 253.8393,
#                            '4-cost_by_individual': 119.6341},
#  ('Arizona', 'Aug 2019'): {'0-household_participation': 374946.0,
#                            '1-individual_participation': 797795.0,
#                            '2-total_cost': 96298934.0,
#                            '3-cost_by_household': 256.8341,
#                            '4-cost_by_individual': 120.7064},
#  ('Arizona', 'Dec 2018'): {'0-household_participation': 378525.0,
#                            '1-individual_participation': 813790.0,
#                            '2-total_cost': 97746608.0,
#                            '3-cost_by_household': 258.2303,
#                            '4-cost_by_individual': 120.1128},
# ...

# %%
sheet = book.sheet_by_name('SWRO')

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Arizona', '', '', '', '', '']
# 8 ['Oct 2018', 386130.0, 834518.0, 100656542.0, 260.6804, 120.6164]
# 9 ['Nov 2018', 381440.0, 823176.0, 98897848.0, 259.275, 120.1418]
# 10 ['Dec 2018', 378525.0, 813790.0, 97746608.0, 258.2303, 120.1128]
# 11 ['Jan 2019 /2', 381800.0, 815689.0, 182138762.0, 477.0528, 223.2944]
# 12 ['Feb 2019 /2', 29081.0, 62271.0, 6925223.0, 238.1357, 111.211]
# 13 ['Mar 2019', 367418.0, 779723.0, 92956039.0, 252.9981, 119.2167]
# 14 ['Apr 2019', 362808.0, 769805.0, 92094926.0, 253.8393, 119.6341]
# 15 ['May 2019', 363819.0, 773157.0, 92665456.0, 254.7021, 119.8533]
# 16 ['Jun 2019', 368339.0, 783815.0, 94309681.0, 256.0404, 120.3214]
# 17 ['Jul 2019', 371735.0, 790722.0, 95736659.0, 257.5401, 121.075]
# 18 ['Aug 2019', 374946.0, 797795.0, 96298934.0, 256.8341, 120.7064]
# 19 ['Sep 2019', 375236.0, 798130.0, 96285536.0, 256.5999, 120.6389]
# 20 ['Total', 345106.4167, 736882.5833, 1146712214.0, 276.89821666666666, 129.68056666666666]
# ...

# %%
data6 = {}

for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [7,22,37,52,67,82,97,112,127,142]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [21,36,51,66,81,96,111,126,141]:
        #for the rows that have blanks
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data6[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data6)
# Out:
# {('Arizona', 'Apr 2019'): {'0-household_participation': 362808.0,
#                            '1-individual_participation': 769805.0,
#                            '2-total_cost': 92094926.0,
#                            '3-cost_by_household': 253.8393,
#                            '4-cost_by_individual': 119.6341},
#  ('Arizona', 'Aug 2019'): {'0-household_participation': 374946.0,
#                            '1-individual_participation': 797795.0,
#                            '2-total_cost': 96298934.0,
#                            '3-cost_by_household': 256.8341,
#                            '4-cost_by_individual': 120.7064},
#  ('Arizona', 'Dec 2018'): {'0-household_participation': 378525.0,
#                            '1-individual_participation': 813790.0,
#                            '2-total_cost': 97746608.0,
#                            '3-cost_by_household': 258.2303,
#                            '4-cost_by_individual': 120.1128},
# ...

# %%
sheet = book.sheet_by_name('MPRO')

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Colorado', '', '', '', '', '']
# 8 ['Oct 2018', 226581.0, 461659.0, 54137256.0, 238.9311, 117.2668]
# 9 ['Nov 2018', 227958.0, 462062.0, 54295937.0, 238.184, 117.5079]
# 10 ['Dec 2018', 226803.0, 456585.0, 54203856.0, 238.9909, 118.7158]
# 11 ['Jan 2019 /2', 227731.0, 456786.0, 101867828.0, 447.3165, 223.01]
# 12 ['Feb 2019 /2', 14711.0, 31018.0, 5563741.0, 378.2028, 179.3714]
# 13 ['Mar 2019', 227236.0, 452616.0, 53800677.0, 236.7612, 118.8661]
# 14 ['Apr 2019', 224890.0, 447801.0, 53085578.0, 236.0513, 118.5473]
# 15 ['May 2019', 224148.0, 446093.0, 52915128.0, 236.0723, 118.6191]
# 16 ['Jun 2019', 223919.0, 445289.0, 52779262.0, 235.7069, 118.5281]
# 17 ['Jul 2019', 224136.0, 444626.0, 52626797.0, 234.7985, 118.3619]
# 18 ['Aug 2019', 222430.0, 440612.0, 52125498.0, 234.3456, 118.3025]
# 19 ['Sep 2019', 222430.0, 438326.0, 51598193.0, 231.975, 117.7165]
# 20 ['Total', 207747.75, 415289.4167, 638999751.0, 256.32036666666664, 128.22378333333333]
# 21 ['', '', '', '', '', '']
# ...

# %%
data7 = {}

for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [7,22,37,52,67,82,97,112,127,142]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [21,36,51,66,81,96,111,126,141]:
        #for the rows that have blanks
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data7[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data7)
# Out:
# {('Colorado', 'Apr 2019'): {'0-household_participation': 224890.0,
#                             '1-individual_participation': 447801.0,
#                             '2-total_cost': 53085578.0,
#                             '3-cost_by_household': 236.0513,
#                             '4-cost_by_individual': 118.5473},
#  ('Colorado', 'Aug 2019'): {'0-household_participation': 222430.0,
#                             '1-individual_participation': 440612.0,
#                             '2-total_cost': 52125498.0,
#                             '3-cost_by_household': 234.3456,
#                             '4-cost_by_individual': 118.3025},
#  ('Colorado', 'Dec 2018'): {'0-household_participation': 226803.0,
#                             '1-individual_participation': 456585.0,
#                             '2-total_cost': 54203856.0,
#                             '3-cost_by_household': 238.9909,
#                             '4-cost_by_individual': 118.7158},
# ...

# %%
sheet = book.sheet_by_name('WRO')

# %%
for i in range(7, sheet.nrows):
    row = sheet.row_values(i)
    print (i,row)
# Out:
# 7 ['Alaska', '', '', '', '', '']
# 8 ['Oct 2018', 32487.0, 71775.0, 12145236.0, 373.8491, 169.2126]
# 9 ['Nov 2018', 37781.0, 83956.0, 13954208.0, 369.3446, 166.2086]
# 10 ['Dec 2018', 37928.0, 84575.0, 14174180.0, 373.7128, 167.593]
# 11 ['Jan 2019 /2', 38796.0, 86305.0, 26171765.0, 674.5996, 303.2474]
# 12 ['Feb 2019 /2', 6167.0, 14683.0, 2305103.0, 373.7803, 156.9913]
# 13 ['Mar 2019', 38972.0, 86284.0, 14439030.0, 370.4975, 167.3431]
# 14 ['Apr 2019', 39433.0, 87526.0, 14676186.0, 372.1803, 167.678]
# 15 ['May 2019', 39133.0, 86836.0, 14588239.0, 372.7861, 167.9976]
# 16 ['Jun 2019', 39241.0, 87307.0, 14748405.0, 375.8417, 168.9258]
# 17 ['Jul 2019', 38892.0, 86605.0, 14818525.0, 381.0173, 171.1047]
# 18 ['Aug 2019', 38756.0, 86185.0, 14664325.0, 378.3756, 170.1494]
# 19 ['Sep 2019', 38335.0, 85147.0, 14406470.0, 375.8046, 169.1953]
# 20 ['Total', 35493.4167, 78932.0, 171091672.0, 401.6981333333333, 180.631925]
# 21 ['', '', '', '', '', '']
# ...

# %%
data8 = {}

for i in range(7, sheet.nrows):#Start at 7 b/c data starts here
    
    row = sheet.row_values(i)
    
    if i in [7,22,37,52,67,82,97,112,127,142]:
        #for the rows that have the state names
        state = row[0]
        if state == 'Footnotes:':
            break
        else:
            continue
            
    if i in [21,36,51,66,81,96,111,126,141]:
        #for the rows that have blanks
        continue
        
     

    month = row[0]
    
    household_participation = row[1]
    
    individual_participation = row[2] 
    
    total_cost = row[3]
    
    cost_by_household = row[4]
    
    cost_by_individual = row[5]
    
    data8[(state, month)] = {
        '0-household_participation': household_participation,
        '1-individual_participation': individual_participation,
        '2-total_cost' : total_cost,
        '3-cost_by_household' : cost_by_household,
        '4-cost_by_individual': cost_by_individual,
    }
    
    
    #print(state, month, household_participation, individual_participation, total_cost, cost_by_household, cost_by_individual)
    

pprint.pprint(data8)
# Out:
# {('Alaska', 'Apr 2019'): {'0-household_participation': 39433.0,
#                           '1-individual_participation': 87526.0,
#                           '2-total_cost': 14676186.0,
#                           '3-cost_by_household': 372.1803,
#                           '4-cost_by_individual': 167.678},
#  ('Alaska', 'Aug 2019'): {'0-household_participation': 38756.0,
#                           '1-individual_participation': 86185.0,
#                           '2-total_cost': 14664325.0,
#                           '3-cost_by_household': 378.3756,
#                           '4-cost_by_individual': 170.1494},
#  ('Alaska', 'Dec 2018'): {'0-household_participation': 37928.0,
#                           '1-individual_participation': 84575.0,
#                           '2-total_cost': 14174180.0,
#                           '3-cost_by_household': 373.7128,
#                           '4-cost_by_individual': 167.593},
# ...
