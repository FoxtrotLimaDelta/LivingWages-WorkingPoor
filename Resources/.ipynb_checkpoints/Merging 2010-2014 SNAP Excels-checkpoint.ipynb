# %%
import os
import pandas as pd
cwd = os.path.abspath('') 
files = os.listdir(cwd)

# %%
cwd
# Out:
# 'C:\\Users\\Denise\\Desktop\\LivingWagesRepo\\LivingWages-WorkingPoor\\Resources'

# %%
files
# Out:
# ['.ipynb_checkpoints',
#  'DLF_pars.snap.ipynb',
#  'EPI Data Library - Medianaverage hourly wages Ed.csv',
#  'FY10.xls',
#  'FY11.xls',
#  'FY12.xls',
#  'FY13.xls',
#  'FY14.xls',
#  'hlthaff.21.2.31.pdf',
#  'LivingWagesWorkingPoor.xlsx',
#  'NHE MedicaidCHIP 1960-2019.csv',
#  'parse_snap.ipynb',
#  'parse_snap_complete.ipynb',
#  'parse_tanf_abrams.ipynb',
#  'parse_tanf_complete_abrams.ipynb',
#  'SNAP',
#  'TANF',
#  'tanf_complete_FLY.ipynb',
#  'Test 1 Merging Excels .ipynb',
#  'Test 2 Merging Excels.ipynb',
#  'Test 3 Merging Excels.ipynb',
#  'Test 4 Merging Excels.ipynb',
#  'US_A.CSV',
#  'US_B.CSV']

# %%
df_total = pd.DataFrame()
for file in files:  # loop through Excel files
    if file.endswith('.xls'):
        excel_file = pd.ExcelFile(file)
        sheets = excel_file.sheet_names
        for sheet in sheets: # loop through sheets inside an Excel file
            df = excel_file.parse(sheet_name = sheet)
            df_total = df_total.append(df)
df_total.to_excel('SNAP_combined_2010-2014.xls')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df.head(100)
# Out:
#    National Data Bank Version 8.2 - Supplemental Nutrition Assistance Program  \
# 0   SNAP Monthly State Participation and Benefit S...
# 1                               Fiscal Year and Month
# 2                                                 NaN
# 3                                                 NaN
# 4                                          US Summary
# 5                                            Oct 2013
# 6                                            Nov 2013
# 7                                            Dec 2013
# 8                                            Jan 2014
# 9                                            Feb 2014
# 10                                           Mar 2014
# 11                                           Apr 2014
# 12                                           May 2014
# 13                                           Jun 2014
# 14                                           Jul 2014
# 15                                           Aug 2014
# 16                                           Sep 2014
# 17                                              Total
# 18                                                NaN
# 19                                                NaN
# 20              1. FNS-388 data. Totals are averaged.
# 21                       ALL DATA SUBJECT TO REVISION
#
#                                     Unnamed: 1   Unnamed: 2  \
# 0                                          NaN          NaN
# 1                             Participation 1/          NaN
# 2                                    Household      Persons
# 3   ----------------- Number -----------------          NaN
# 4                                          NaN          NaN
# 5                                     23053620     47415754
# 6                                     23014953     47363175
# 7                                     22860771     47078649
# 8                                     22646436     46530889
# 9                                     22597843     46515743
# 10                                    22580029     46390386
# 11                                    22663868     46514290
# 12                                    22604943     46235606
# 13                                    22713859     46495793
# 14                                    22716152     46486888
# 15                                    22724505     46476291
# 16                                    22749951     46459930
# 17                                 2.27439e+07  4.66636e+07
# 18                                         NaN          NaN
# 19                                         NaN          NaN
# 20                                         NaN          NaN
# 21                                         NaN          NaN
#
#                                            Unnamed: 3  Unnamed: 4   11/06/2015
# 0                                                 NaN         NaN          NaN
# 1                                             Benefit         NaN          NaN
# 2                                       Per Household  Per Person         Cost
# 3   ----------------------------------------------...         NaN          NaN
# 4                                                 NaN         NaN          NaN
# 5                                             275.668      134.03   6355133852
# 6                                             257.503     125.127   5926416528
# 7                                             254.513     123.588   5818353479
# 8                                             254.564     123.896   5764971510
# 9                                             254.792     123.781   5757748409
# 10                                             255.76     124.488   5775057723
# 11                                            254.451      123.98   5766848260
# 12                                            255.786     125.056   5782022930
# 13                                            254.038     124.101   5770182054
# 14                                            254.236     124.234   5775265294
# 15                                            253.732     124.062   5765935451
# 16                                            252.348     123.567   5740900079
# 17                                            256.475     125.006  69998835569
# 18                                                NaN         NaN          NaN
# 19                                                NaN         NaN          NaN
# 20                                                NaN         NaN          NaN
# 21                                                NaN         NaN          NaN
